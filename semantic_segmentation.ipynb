# %%
! git clone https://github.com/jayantabh/semantic-segmentation-pytorch.git
# Out:
# Cloning into 'semantic-segmentation-pytorch'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 1059 (delta 1), reused 10 (delta 0), pack-reused 1038
# Receiving objects: 100% (1059/1059), 4.57 MiB | 9.96 MiB/s, done.
# Resolving deltas: 100% (635/635), done.

# %%
# %cd semantic-segmentation-pytorch/
# Out:
# /content/semantic-segmentation-pytorch

# %% [markdown]
# Model 1: ade20k-resnet50dilated-ppm_deepsup
#
# Model 2: ade20k-mobilenetv2dilated-c1_deepsup

# %%
! pip install yacs

# %%
! ./demo_test.sh
# Out:
# --2020-05-02 18:56:12--  http://sceneparsing.csail.mit.edu/model/pytorch/ade20k-resnet50dilated-ppm_deepsup/encoder_epoch_20.pth
# Resolving sceneparsing.csail.mit.edu (sceneparsing.csail.mit.edu)... 128.30.100.255
# Connecting to sceneparsing.csail.mit.edu (sceneparsing.csail.mit.edu)|128.30.100.255|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 95015426 (91M)
# Saving to: ‘ade20k-resnet50dilated-ppm_deepsup/encoder_epoch_20.pth’
#
# encoder_epoch_20.pt 100%[===================>]  90.61M  25.6MB/s    in 3.9s
#
# 2020-05-02 18:56:17 (23.4 MB/s) - ‘ade20k-resnet50dilated-ppm_deepsup/encoder_epoch_20.pth’ saved [95015426/95015426]
#
# --2020-05-02 18:56:17--  http://sceneparsing.csail.mit.edu/model/pytorch/ade20k-resnet50dilated-ppm_deepsup/decoder_epoch_20.pth
# Resolving sceneparsing.csail.mit.edu (sceneparsing.csail.mit.edu)... ^C

# %%
! ./download_ADE20K.sh
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./data/ADEChallengeData2016/annotations/training/ADE_train_00002526.png
#   inflating: ./data/ADEChallengeData2016/annotations/training/ADE_train_00002954.png
#   inflating: ./data/ADEChallengeData2016/annotations/training/ADE_train_00007278.png
#   inflating: ./data/ADEChallengeData2016/annotations/training/ADE_train_00012415.png
#   inflating: ./data/ADEChallengeData2016/annotations/training/ADE_train_00012867.png
#   inflating: ./data/ADEChallengeData2016/annotations/training/ADE_train_00000612.png
#   inflating: ./data/ADEChallengeData2016/annotations/training/ADE_train_00016979.png
#   inflating: ./data/ADEChallengeData2016/annotations/training/ADE_train_00013255.png
#   inflating: ./data/ADEChallengeData2016/annotations/training/ADE_train_00013980.png
#   inflating: ./data/ADEChallengeData2016/annotations/training/ADE_train_00001052.png
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cp /content/drive/My\ Drive/sem_seg/validation.odgt /content/semantic-segmentation-pytorch/data/

# %%
# %mkdir ckpt

# %%
# %mkdir ckpt/ade20k-resnet50dilated-ppm_deepsup/
# %cp ade20k-resnet50dilated-ppm_deepsup/* ckpt/ade20k-resnet50dilated-ppm_deepsup/

# %%
# %mkdir ckpt/ade20k-mobilenetv2dilated-c1_deepsup
# %cd ckpt/ade20k-mobilenetv2dilated-c1_deepsup
! wget http://sceneparsing.csail.mit.edu/model/pytorch/ade20k-mobilenetv2dilated-c1_deepsup/decoder_epoch_20.pth
! wget http://sceneparsing.csail.mit.edu/model/pytorch/ade20k-mobilenetv2dilated-c1_deepsup/encoder_epoch_20.pth
# Out:
# /content/semantic-segmentation-pytorch/ckpt/ade20k-mobilenetv2dilated-c1_deepsup
# --2020-05-02 19:02:30--  http://sceneparsing.csail.mit.edu/model/pytorch/ade20k-mobilenetv2dilated-c1_deepsup/decoder_epoch_20.pth
# Resolving sceneparsing.csail.mit.edu (sceneparsing.csail.mit.edu)... 128.30.100.255
# Connecting to sceneparsing.csail.mit.edu (sceneparsing.csail.mit.edu)|128.30.100.255|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1486984 (1.4M)
# Saving to: ‘decoder_epoch_20.pth’
#
# decoder_epoch_20.pt 100%[===================>]   1.42M  2.34MB/s    in 0.6s
#
# 2020-05-02 19:02:31 (2.34 MB/s) - ‘decoder_epoch_20.pth’ saved [1486984/1486984]
#
# --2020-05-02 19:02:32--  http://sceneparsing.csail.mit.edu/model/pytorch/ade20k-mobilenetv2dilated-c1_deepsup/encoder_epoch_20.pth
# Resolving sceneparsing.csail.mit.edu (sceneparsing.csail.mit.edu)... 128.30.100.255
# ...

# %%
# %mkdir ckpt/ade20k-hrnetv2-c1
# %cd ckpt/ade20k-hrnetv2-c1
! wget http://sceneparsing.csail.mit.edu/model/pytorch/ade20k-hrnetv2-c1/decoder_epoch_30.pth
! wget http://sceneparsing.csail.mit.edu/model/pytorch/ade20k-hrnetv2-c1/encoder_epoch_30.pth
# Out:
# /content/semantic-segmentation-pytorch/ckpt/ade20k-hrnetv2-c1
# --2020-05-02 19:18:37--  http://sceneparsing.csail.mit.edu/model/pytorch/ade20k-hrnetv2-c1/decoder_epoch_30.pth
# Resolving sceneparsing.csail.mit.edu (sceneparsing.csail.mit.edu)... 128.30.100.255
# Connecting to sceneparsing.csail.mit.edu (sceneparsing.csail.mit.edu)|128.30.100.255|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4780389 (4.6M)
# Saving to: ‘decoder_epoch_30.pth’
#
# decoder_epoch_30.pt 100%[===================>]   4.56M  5.67MB/s    in 0.8s
#
# 2020-05-02 19:18:38 (5.67 MB/s) - ‘decoder_epoch_30.pth’ saved [4780389/4780389]
#
# --2020-05-02 19:18:39--  http://sceneparsing.csail.mit.edu/model/pytorch/ade20k-hrnetv2-c1/encoder_epoch_30.pth
# Resolving sceneparsing.csail.mit.edu (sceneparsing.csail.mit.edu)... 128.30.100.255
# Connecting to sceneparsing.csail.mit.edu (sceneparsing.csail.mit.edu)|128.30.100.255|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
# %cd /content/semantic-segmentation-pytorch/
! python attacks_main.py --cfg /content/semantic-segmentation-pytorch/config/ade20k-hrnetv2.yaml
# Out:
# /content/semantic-segmentation-pytorch
# [2020-05-02 19:18:52,903 INFO attacks_main.py line 471 572] Loaded configuration file /content/semantic-segmentation-pytorch/config/ade20k-hrnetv2.yaml
# [2020-05-02 19:18:52,904 INFO attacks_main.py line 472 572] Running with config:
# ATTACK:
#   alpha: 0.5
#   batch_size: 1
#   do_max_pert: True
#   eps: 0.25
#   method: fgsm
#   num_iters: 500
#   orig_save_pred: False
#   orig_save_pred_img: True
#   output_dir: ./output/
#   pert_save_pred: True
#   pert_save_pred_img: True
#   save_pert_image: False
#   target_idx: 0
#   use_val: True
# DATASET:
#   imgMaxSize: 1000
#   imgSizes: (300, 375, 450, 525, 600)
#   list_train: ./data/training.odgt
#   list_val: ./data/validation.odgt
#   num_class: 150
#   padding_constant: 32
#   random_flip: True
#   root_dataset: ./data/
#   segm_downsampling_rate: 4
# DIR: ckpt/ade20k-hrnetv2-c1
# MODEL:
#   arch_decoder: c1
#   arch_encoder: hrnetv2
#   fc_dim: 720
#   weights_decoder:
# ...

# %%
! zip -r pert_model_1.zip data/pert
# Out:
#   adding: data/pert/ (stored 0%)
#   adding: data/pert/ADE_val_00000035.png (deflated 0%)
#   adding: data/pert/ADE_val_00000023.png (deflated 0%)
#   adding: data/pert/ADE_val_00000091.png (deflated 0%)
#   adding: data/pert/ADE_val_00000011.png (deflated 0%)
#   adding: data/pert/ADE_val_00000067.png (deflated 0%)
#   adding: data/pert/ADE_val_00000056.png (deflated 0%)
#   adding: data/pert/ADE_val_00000006.png (deflated 0%)
#   adding: data/pert/ADE_val_00000039.png (deflated 0%)
#   adding: data/pert/ADE_val_00000059.png (deflated 0%)
#   adding: data/pert/ADE_val_00000034.png (deflated 0%)
#   adding: data/pert/ADE_val_00000001.png (deflated 0%)
#   adding: data/pert/ADE_val_00000029.png (deflated 0%)
#   adding: data/pert/ADE_val_00000070.png (deflated 0%)
#   adding: data/pert/ADE_val_00000022.png (deflated 0%)
#   adding: data/pert/ADE_val_00000028.png (deflated 0%)
#   adding: data/pert/ADE_val_00000009.png (deflated 0%)
# ...

# %%
! zip -r output.zip output/
# Out:
#   adding: output/ (stored 0%)
#   adding: output/pred/ (stored 0%)
#   adding: output/pred/pert_image_ADE_val_00000063.png (stored 0%)
#   adding: output/pred/pert_image_ADE_val_00000078.png (deflated 8%)
#   adding: output/pred/pert_pred_ADE_val_00000002.png.npy (deflated 100%)
#   adding: output/pred/orig_image_ADE_val_00000032.png (deflated 21%)
#   adding: output/pred/pert_image_ADE_val_00000069.png (stored 0%)
#   adding: output/pred/pert_pred_ADE_val_00000067.png.npy (deflated 99%)
#   adding: output/pred/pert_pred_ADE_val_00000016.png.npy (deflated 99%)
#   adding: output/pred/pert_image_ADE_val_00000059.png (deflated 1%)
#   adding: output/pred/pert_pred_ADE_val_00000039.png.npy (deflated 100%)
#   adding: output/pred/pert_pred_ADE_val_00000086.png.npy (deflated 99%)
#   adding: output/pred/orig_image_ADE_val_00000055.png (deflated 8%)
#   adding: output/pred/pert_image_ADE_val_00000079.png (deflated 5%)
#   adding: output/pred/orig_image_ADE_val_00000056.png (deflated 24%)
# ...

# %%
# %cp *.zip /content/drive/My\ Drive/sem_seg

# %%
drive.flush_and_unmount()

# %%
! rm -rf /content/semantic-segmentation-pytorch/output/*
! rm -rf /content/semantic-segmentation-pytorch/data/pert/*
! rm -rf output.zip
! rm -rf pert_model_1.zip
